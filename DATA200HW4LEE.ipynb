# %%
import pandas as pd
import numpy as np
import streamlit as st
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv("Real_estate.csv")

df.head()
# Out:
#    No  transaction_date  house_age  distance_to_the_nearest_MRT_station  \
# 0   1          2012.917       32.0                             84.87882
# 1   2          2012.917       19.5                            306.59470
# 2   3          2013.583       13.3                            561.98450
# 3   4          2013.500       13.3                            561.98450
# 4   5          2012.833        5.0                            390.56840
#
#    number_of_convenience_stores  latitude  longitude  house_price_of_unit_area
# 0                            10  24.98298  121.54024                      37.9
# 1                             9  24.98034  121.53951                      42.2
# 2                             5  24.98746  121.54391                      47.3
# 3                             5  24.98746  121.54391                      54.8
# 4                             5  24.97937  121.54245                      43.1

# %%
 df_flower = pd.read_csv("mountain_flowers.csv")
 df_flower.head()
# Out:
#    petal_length  petal_width    name
# 0           1.4          0.2  violet
# 1           1.4          0.2  violet
# 2           1.3          0.2  violet
# 3           1.5          0.2  violet
# 4           1.4          0.2  violet

# %%
# number of convenience stores vs house price of unit area
# distance to the nearest MRT station vs house price of unit area

df_conv_area = df.loc[:, ['distance_to_the_nearest_MRT_station', 'number_of_convenience_stores','house_price_of_unit_area']]
df_conv_area
# Out:
#      distance_to_the_nearest_MRT_station  number_of_convenience_stores  \
# 0                               84.87882                            10
# 1                              306.59470                             9
# 2                              561.98450                             5
# 3                              561.98450                             5
# 4                              390.56840                             5
# ..                                   ...                           ...
# 409                           4082.01500                             0
# 410                             90.45606                             9
# 411                            390.96960                             7
# 412                            104.81010                             5
# 413                             90.45606                             9
#
#      house_price_of_unit_area
# 0                        37.9
# 1                        42.2
# ...

# %%
fig = px.scatter(df_conv_area, x="distance_to_the_nearest_MRT_station", y="house_price_of_unit_area", title="The factors that decides house price")

# %%
st.plotly_chart(fig)
# Out:
# 2023-10-05 02:11:25.652
# ...
#   command:
#
#     streamlit run /Users/sungwonlee/anaconda3/envs/Data200SungwonL/lib/python3.11/site-packages/ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator()

# %%
df_conv_area = df.loc[:, ['house_age', 'distance_to_the_nearest_MRT_station', 'number_of_convenience_stores','house_price_of_unit_area']]

# %%
df_conv_area[(df_conv_area['distance_to_the_nearest_MRT_station'] > 100) & (df_conv_area['distance_to_the_nearest_MRT_station']< 200 )]
# Out:
#      house_age  distance_to_the_nearest_MRT_station  \
# 65        40.1                             123.7429
# 66         1.0                             193.5845
# 67         8.5                             104.8101
# 82        13.2                             150.9347
# 94        40.9                             167.5989
# 95         8.0                             104.8101
# 101       12.7                             170.1289
# 102        1.1                             193.5845
# 106       17.2                             189.5181
# 110        8.1                             104.8101
# 111       33.3                             196.6172
# 114       30.6                             143.8383
# 123        0.0                             185.4296
# 125        1.1                             193.5845
# 128       41.3                             124.9912
# 134       33.4                             186.9686
# 146        0.0                             185.4296
# ...

# %%
df_conv_area['house_age'].max()
# Out:
# 43.8
